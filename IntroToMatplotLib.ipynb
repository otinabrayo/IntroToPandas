# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.show()

# %%
plt.show([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
plt.show(x, y);

# %%
# 1st method
fig = plt.figure()  # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a fig
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # adds some data
plt.show()

# %%
# 3rd method
fig, ax = plt.subplots()
ax.plot(x, [12, 30, 38, 48]); #add some data
plt.show()
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(5, 5)) # (width, height)

# 3. Plot the data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save and show (u save the whole figure)
fig.savefig("images/sample-plot.png")
plt.show()

# %% [markdown]
# ## Making figures with Numpy arrays
#
# We want :
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
# Create some data
x = np.linspace(0, 10, 100)
x[: 10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
# Use the same data and create scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
# Another scater plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %%
# Make a plot from dictionary
nutButter = {"Almond Butter": 10,
             "Peanut Butter": 8,
             "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nutButter.keys(), nutButter.values())
ax.set(title= "Nut Butter Store",
      ylabel= "Price ($)")
plt.show()

# %%
# Bar graph in horizontal
fig, ax = plt.subplots()
ax.barh(nutButter.keys(), nutButter.values())
plt.show()

# %%
# Make some data for Histogram and plot it
x = np.random.randn(1000)
x[: 20]
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ## Two options  for subplots

# %%
# Option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))
# Plot to each diff axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nutButter.keys(), nutButter.values())
ax4.hist(np.random.randn(1000))
plt.show()

# %%
# Option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))
# Plot to each diff index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nutButter.keys(), nutButter.values())
ax[1, 1].hist(np.random.randn(1000))
plt.show()

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
# Make a dataframe
carSales2 = pd.read_csv("car-sales.csv")
carSales2
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum().plot()
plt.show()

# %%
# code that removes the $ , . from the Price column, eliminates the cents and converts it to an integer
carSales2['Price'] = carSales2['Price'].str.replace(r'[\$,]', '', regex=True).astype(float).astype(int)
carSales2
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
carSales2["Sale Date"] = pd.date_range("1/1/2020", periods=len(carSales2))
carSales2
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
carSales2["Total Sales"] = carSales2["Price"].cumsum()
carSales2
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Lets plot the total sales
carSales2.plot(x="Sale Date",
               y="Total Sales")
plt.show()

# %%
carSales2.plot(x="Odometer (KM)",
               y="Price", 
               kind="scatter")
plt.show()

# %%
# How about a bar graph
x = np.random.rand(10, 4)
x

df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.569295  0.286550  0.357924  0.164967
# 1  0.460200  0.086365  0.308105  0.269722
# 2  0.596268  0.586311  0.586453  0.459061
# 3  0.623613  0.652300  0.795876  0.944023
# 4  0.994543  0.030430  0.739485  0.618729
# 5  0.216906  0.912655  0.414779  0.653092
# 6  0.541241  0.830326  0.706622  0.353136
# 7  0.578053  0.848899  0.639486  0.720967
# 8  0.097510  0.270762  0.895391  0.034992
# 9  0.126089  0.658538  0.397637  0.014085

# %%
df.plot.bar()
plt.show()

# %%
df.plot(kind="bar")
plt.show()

# %%
carSales2
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
carSales2.plot(x="Make", y="Odometer (KM)", kind="bar")
plt.show()

# %%
# How about Histogram 
carSales2["Odometer (KM)"].plot.hist()
plt.show()

# %%
carSales2["Odometer (KM)"].plot(kind="hist")
plt.show()

# %%
carSales2["Odometer (KM)"].plot.hist(bins=20)
plt.show()

# %%
# Lets try on another data sales
heartDis = pd.read_csv("heart-disease.csv")
heartDis
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a Histogram of age
heartDis.age.plot.hist(bins=10)
plt.show()

# %%
heartDis.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heartDis.plot.hist(figsize=(10, 30), subplots=True)
plt.show()

# %% [markdown]
# ### Which One shoul I use ? Pyplot vs Matplotlib
#
# * When ploting something quickly use pyplot method
# * When ploting a more advanced , use the OO method

# %%
over50 = heartDis[heartDis.age > 50]
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# PYPLOT METHOD
over50.plot(kind="scatter",
            x="age", 
            y="chol", 
            c="target")
plt.show()

# %%
# OO METHOD mixed with pyplot method
fix, ax = plt.subplots(figsize=(10, 6))
over50.plot(kind="scatter",
            x="age", 
            y="chol", 
            c="target",
            ax=ax)
# ax.set_xlim([60, 65])
plt.show()

# %%
# Object Orient Method from scratch
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(x=over50.age, 
                     y=over50.chol, 
                     c=over50.target)

# Customize
ax.set(title="Heart Disease and Cholestrol levels", 
       xlabel="Age", 
       ylabel="Cholestrol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line showing mean
ax.axhline(over50.chol.mean(), 
           linestyle="--")

plt.show()

# %%
# susbplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               figsize=(10, 10),
                               sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over50.age, y=over50.chol, c=over50.target)

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", 
        ylabel="Cholestrol")

# Add a legend 
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line showing mean
ax0.axhline(over50.chol.mean(), 
           linestyle="--")

# Add data to ax1
scatter =  ax1.scatter(x=over50.age, y=over50.thalach, c=over50.target)

ax1.set(title="Heart Disease and Max Heart Rate", 
        xlabel="Age", 
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

ax1.axhline(y=over50.thalach.mean(), 
            linestyle="--")

# Add a title to the figure 
fig.suptitle("HEART DISEASE ANALYSIS", fontsize=15, fontweight="bold")

plt.show()

# %% [markdown]
# ## Customizing matplotlib and different styles

# %%
# 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
carSales2.Price.plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8')

# %%
carSales2.Price.plot()
plt.show()

# %%
carSales2.plot(x="Odometer (KM)",
               y="Price", 
               kind="scatter")
plt.show()

# %%
plt.style.use('ggplot')
carSales2.Price.plot()
plt.show()

# %%
# create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.50964589,  1.13587602, -1.86176872, -1.75365933],
#        [-1.78287963, -0.42010937, -0.77020301, -0.28502838],
#        [-0.42002126,  2.09482215,  0.01431497, -0.98147591],
#        [ 0.6142527 , -0.05259179,  0.35640483, -1.95338493],
#        [-0.78123574, -1.28193381, -0.85872419,  0.16458127],
#        [-0.57362471, -0.60266794, -0.73773069, -2.10725179],
#        [ 0.99442505, -0.65329221,  0.83892721, -1.01374148],
#        [ 2.02563976, -0.11602682, -0.50675582,  0.60256428],
#        [ 1.61365795,  0.64419634, -1.28549158, -1.36775463],
#        [ 0.75914947, -0.88306445, -1.43826773,  1.37111204]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.509646  1.135876 -1.861769 -1.753659
# 1 -1.782880 -0.420109 -0.770203 -0.285028
# 2 -0.420021  2.094822  0.014315 -0.981476
# 3  0.614253 -0.052592  0.356405 -1.953385
# 4 -0.781236 -1.281934 -0.858724  0.164581
# 5 -0.573625 -0.602668 -0.737731 -2.107252
# 6  0.994425 -0.653292  0.838927 -1.013741
# 7  2.025640 -0.116027 -0.506756  0.602564
# 8  1.613658  0.644196 -1.285492 -1.367755
# 9  0.759149 -0.883064 -1.438268  1.371112

# %%
ax = df.plot(kind="bar")
plt.show()

# %%
# Customize our plot with the set() method
ax = df.plot(kind="bar")
ax.set(title="Random Bar Graph From DataFrame", 
       xlabel="Row Number", 
       ylabel="Random Number")

ax.legend().set_visible(True)
plt.show()

# %%
# Object Orient Method from scratch
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(x=over50.age, 
                     y=over50.chol, 
                     c=over50.target, 
                     cmap="winter")

# Customize
ax.set(title="Heart Disease and Cholestrol levels", 
       xlabel="Age", 
       ylabel="Cholestrol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line showing mean
ax.axhline(over50.chol.mean(), 
           linestyle="--")

plt.show()

# %%
# Customizing the x and y limitations
# susbplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               figsize=(10, 10),
                               sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over50.age, 
                      y=over50.chol, 
                      c=over50.target, 
                      cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", 
        ylabel="Cholestrol")
ax0.set_xlim([50, 80])

# Add a legend 
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line showing mean
ax0.axhline(over50.chol.mean(), 
           linestyle="--")

# Add data to ax1
scatter =  ax1.scatter(x=over50.age, 
                       y=over50.thalach, 
                       c=over50.target, 
                       cmap="winter")

ax1.set(title="Heart Disease and Max Heart Rate", 
        xlabel="Age", 
        ylabel="Max Heart Rate")
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])

ax1.legend(*scatter.legend_elements(), title="Target")

ax1.axhline(y=over50.thalach.mean(), 
            linestyle="--")

# Add a title to the figure 
fig.suptitle("HEART DISEASE ANALYSIS", fontsize=15, fontweight="bold")

plt.show()

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
